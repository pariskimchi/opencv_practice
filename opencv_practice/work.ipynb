# %%
import cv2 
import numpy as np

mode = True


back = np.ones((512,512), dtype=np.uint8)*255

for i in range(50,510,100):
    back = cv2.line(back,(i,0),(i,511),(0,0,0),2)
    back = cv2.line(back,(0,i),(511,i),(0,0,0),2)
#     for j in range(50,510,100):
#         back = cv2.circle(back,(i,j),10,(0,255,0),5)   


#범위 설정 고정함수




def draw_circle(event,x,y,flags,param):
    global  mode
    if event == cv2.EVENT_LBUTTONDOWN:
        c=255 # 바둑알 색깔 흰색, 
        
        if mode:
            c=0 # mode가 True이면 바둑알 검정색으로
            
        mode = not mode
        
        if ((x % 50) < 25) | ((y%50) < 25):
#         cv2.circle(back,(round(x,-2)-50,y))
            cv2.circle(back,(round(x,-2)-50,round(y,-2)-50),20,(c,c,c),-1)
        elif ((x % 50) < 25) | ((y%50) > 25):
            cv2.circle(back,(round(x,-2)-50,round(y,-2)+50),20,(c,c,c),-1)
        elif ((x % 50) > 25) | ((y%50) < 25):
            cv2.circle(back,(round(x,-2)+50,round(y,-2)-50),20,(c,c,c),-1)
        elif ((x % 50) > 25) | ((y%50) >25):
            cv2.circle(back,(round(x,-2)+50,round(y,-2)+50),20,(c,c,c),-1)
        
        rx = (x//10)*val_range
        
        
        
        
        if mode: #바둑알이 흰색일때
            if ((x % 50) < 25) | ((y%50) < 25):
                cv2.circle(back,(round(x,-2)-50,round(y,-2)-50),21,(0,0,0),1)# 바둑알 테두리 그려라 검정색으로
            elif ((x % 50) < 25) | ((y%50) > 25):
                cv2.circle(back,(round(x,-2)-50,round(y,-2)+50),21,(0,0,0),1)
            elif ((x % 50) > 25) | ((y%50) < 25):
                cv2.circle(back,(round(x,-2)+50,round(y,-2)-50),21,(0,0,0),1)  
            elif ((x % 50) > 25) | ((y%50) >25):   
                cv2.circle(back,(round(x,-2)+50,round(y,-2)+50),21,(0,0,0),1)                  
                
        
        cv2.imshow('back',back)





cv2.namedWindow('back')
cv2.setMouseCallback('back',draw_circle)

cv2.imshow('back',back)
# cv2.imshow('img',img)

cv2.waitKey(0)
cv2.destroyAllwindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-c5a8da8c147f> in <module>
#      68
#      69 cv2.waitKey(0)
# ---> 70 cv2.destroyAllwindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destroyAllwindows'

# %%
back = np.ones((512,512), dtype=np.uint8)*255

for i in range(50,510,100):
    back = cv2.line(back,(i,0),(i,511),(0,0,0),2)
    
    print(i,0)
#     back = cv2.line(back,(0,i),(511,i),(0,0,0),2)
cv2.namedWindow('back')

cv2.imshow('back',back)
# cv2.imshow('img',img)

cv2.waitKey(0)
cv2.destroyAllwindows()
# Out:
# 50 0
# 150 0
# 250 0
# 350 0
# 450 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-6ee5d359e728> in <module>
#      12
#      13 cv2.waitKey(0)
# ---> 14 cv2.destroyAllwindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'destroyAllwindows'

# %%
import cv2 
import numpy as np

mode = True


back = np.ones((800,800), dtype=np.uint8)*255

for i in range(20,781,40):
    back = cv2.line(back,(i,20),(i,780),(0,0,0),2)
    back = cv2.line(back,(20,i),(780,i),(0,0,0),2)
#     for j in range(50,510,100):
#         back = cv2.circle(back,(i,j),10,(0,255,0),5)   


#범위 설정 고정함수

val_range = 40
moitie_range = val_range/2


def draw_circle(event,x,y,flags,param):
    global  mode
    if event == cv2.EVENT_LBUTTONDOWN:
        c=255 # 바둑알 색깔 흰색, 
        
        if mode:
            c=0 # mode가 True이면 바둑알 검정색으로
            
        mode = not mode
        
        
        if ((x % val_range) < moitie_range) | ((y%val_range) < moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
            cv2.circle(back,(round(x,-1)-val_range,round(y,-1)-val_range),20,(c,c,c),-1)        
        elif ((x % val_range) < moitie_range) | ((y%val_range) > moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
            cv2.circle(back,(round(x,-1)-val_range,round(y,-1)+val_range),20,(c,c,c),-1)        
        elif ((x % val_range) > moitie_range) | ((y%val_range) < moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
            cv2.circle(back,(round(x,-1)+val_range,round(y,-1)-val_range),20,(c,c,c),-1)        
        elif ((x % val_range) > moitie_range) | ((y%val_range) >moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
            cv2.circle(back,(round(x,-1)+val_range,round(y,-1)+val_range),20,(c,c,c),-1)        
        
        
        if mode:
            if ((x % val_range) < moitie_range) | ((y%val_range) < moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
                cv2.circle(back,(round(x,-2)-val_range,round(y,-2)-val_range),21,(0,0,0),1)        
            elif ((x % val_range) < moitie_range) | ((y%val_range) > moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
                cv2.circle(back,(round(x,-2)-val_range,round(y,-2)+val_range),21,(0,0,0),1)        
            elif ((x % val_range) > moitie_range) | ((y%val_range) < moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
                cv2.circle(back,(round(x,-2)+val_range,round(y,-2)-val_range),21,(0,0,0),1)        
            elif ((x % val_range) > moitie_range) | ((y%val_range) >moitie_range):
#         cv2.circle(back,(round(x,-2)-50,y))
                cv2.circle(back,(round(x,-2)+val_range,round(y,-2)+val_range),21,(0,0,0),1)       
        
        

        
            
                
        
        cv2.imshow('back',back)





cv2.namedWindow('back')
cv2.setMouseCallback('back',draw_circle)

cv2.imshow('back',back)
# cv2.imshow('img',img)

cv2.waitKey(0)
cv2.destroyAllwindows()
